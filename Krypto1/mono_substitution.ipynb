# %%
from Decrypter import Decrypter
import matplotlib.pyplot as plt

english_freq =    {'E': 13.0, 'T': 9.10, 'A': 8.2, 'O': 7.5, 'I': 6.97, 'N': 6.75, 'S': 6.33,
                  'H': 6.09, 'R': 5.99, 'D': 4.25, 'L': 4.03, 'C': 2.76, 'U': 2.78, 'M': 2.4,
                  'W': 2.4, 'F': 2.02, 'G': 2.36, 'Y': 2.02, 'P': 1.93, 'B': 1.49, 'V': 0.98,
                  'K': 0.77, 'J': 0.15, 'X': 0.15, 'Q': 0.09, 'Z': 0.07}

decrypter = Decrypter("chiffrat.txt")
print(decrypter.chiffrat)
# Out:
# ABPEA OSMU: QLC CV GBVEGPT RSEQK QB QSUC SRSZ CEGMZDQPBE IMBY STT GPQPNCEK.
# DBTPQPGPSEK BIQCE RSME QLSQ GMPYPESTK SMC 'ABPEA OSMU'. QLPK RSMEPEA PK VKCO TPUC QLC SMAVYCEQ QB 'DMBQCGQ QLC GLPTOMCE': QB VEOCMYPEC CEGMZDQPBE.
#
# S ECR GLSDQCM BI QLC GMZDQB RSMK LSK JVKQ XCCE KQSMQCO XZ QLC KRCOPKL DMCKPOCEGZ BI QLC CV GBVEGPT: QLC PEGMCSKCO VKC BI CEGMZDQPBE, DSMQPGVTSMTZ PE YCKKSAPEA SDDK, RBVTO YSUC TSR CEIBMGCYCEQ "XTPEO SEO OCSI". RSMEPEA SASPEKQ GMPYPESTK 'ABPEA OSMU', QLC KRCOPKL DMCKPOCEGZ LSK KQSMQCO OPKGVKKPEA QLC PKKVC RPQL STT CVMBDCSE JVKQPGC SEO LBYC SIISPMK YPEPKQCMK QLPK QLVMKOSZ PE KQBGULBTY. ZCQ, QLCMC PK EB OPTCYYS XCQRCCE KCGVMC, DMPHSQC GBYYVEPGSQPBEK SEO QLC KCGVMPQZ PEQCMCKQK BI KQSQCK - XMCSUPEA CEGMZDQPBE RBVTO KPYDTZ YCSE OCKQMBZPEA KCGVMPQZ KCGVMPQZ.
#
# ABPEA OSMU CFDTSPECO
#
# ABPEA OSMU YCSEK QLSQ S GBYYVEPGSQPBE LSK YBHCO IMBY S DVXTPG GBYYVEPGSQPBE GLSEECT - RLCMC PQ GBVTO XC YBEPQBMCO - QB S DMPHSQC GBYYVEPGSQPBE GLSEECT - RLCMC YBEPQBMPEA PK PYDBKKPXTC. CEGMZDQPBE, IBM PEKQSEGC, STTBRK DCBDTC QB DMBQCGQ QLCPM GBYYVEPGSQPBE IMBY CSHCKOMBDDPEA.
#
# KRCOCE RSMEK BI GMPYPESTK 'ABPEA OSMU'
#
# "OPAPQST KCMHPGCK SMC PEGMCSKPEATZ SXVKCO XZ GMPYPESTK QB GBYYPQ GMPYCK KVGL SK GLPTO KCFVST SXVKC, BETPEC MSDC, IMSVO, MSEKBYRSMC SQQSGUK BM SQQSGUK BE GMPQPGST PEIMSKQMVGQVMC. YBMCBHCM, OPAPQST KCMHPGCK SMC STKB SE PYDBMQSEQ QBBT RPQL RLPGL GMPYPESTK GSE PEKQPASQC, DTSE, SEO GBYYPQ GMPYCK, SEO STKB SOHCMQPKC SEO BIICM GMPYPEST KCMHPGCK SEO LBKQ PTTCAST YSMUCQDTSGCK. PQ PK CSKZ IBM GMPYPESTK QB â€˜AB OSMUâ€™ VEOCM QLCKC GPMGVYKQSEGCK. GMPYPESTK GSE GBYYPQ GMPYCK PE RSZK QLSQ TSR CEIBMGCYCEQ GSEEBQ OCQCGQ SEO PEQCMGCDQ, SEO QLPK PK HSKQTZ ISGPTPQSQCO XZ CEGMZDQPBE-DMBQCGQCO GBYYVEPGSQPBEK", QLC GBVEGPT'K TCSOCMK RMBQC PE S GBYYVEPGSQPBE DMCDSMPEA IBM SE PEIBMYST YCCQPEA BI YCYXCM KQSQCK' PEQCMPBM SEO JVKQPGC YPEPKQCMK PE KQBGULBTY QLPK QLVMKOSZ.
#
# RLPTC QLC KRCOPKL CV DMCKPOCEGZ OBCK EBQ XTSQSEQTZ YCEQPBE QB XMCSU CEO-QB-CEO CEGMZDQPBE, QLC DSDCM OBCK KSZ QLSQ QLCMC PK "QLC ECCO IBM CIICGQPHC SDDMBSGLCK QB CEGMZDQCO GBYYVEPGSQPBE".
#
# ABPEA OSMU: PK QLPK S OPTCYYS XCQRCCE KCGVMC, DMPHSQC GBYYVEPGSQPBEK SEO QLC KCGVMPQZ PEQCMCKQK BI KQSQCK?
#
# DBTPQPGPSEK QCEO QB DMCKCEQ KCGVMC SEO DMPHSQC GBYYVEPGSQPBE SK OSEACMBVK QB KQSQC KCGVMPQZ. QLPK PK S QZDPGST YCQLBO VKCO PE QLC GMZDQB RSMK. QLC SMAVYCEQ XCPEA: QB DMBQCGQ SASPEKQ QLMCSQK TPUC QCMMBMPKY, GLPTO KCFVST SXVKC, SEO YBMC, TSR CEIBMGCYCEQ YVKQ LSHC SGGCKK QB OPAPQST GBYYVEPGSQPBE.
#
# QLC SMAVYCEQSQPBE PE QLC KRCOPKL DSDCM PK QLC KSYC:
#
# "QLC SXBHCYCEQPBECO GBEGCMEK LPALTPALQ QLC ECCO QB OPKGVKK SGGCKK QB GBYYVEPGSQPBEK OSQS SK S ECGCKKSMZ SEO DMBDBMQPBESQC YCSKVMC PE S OCYBGMSQPG KBGPCQZ QB KSICAVSMO QLC DMCHCEQPBE, PEHCKQPASQPBE, OCQCGQPBE BM DMBKCGVQPBE BI GMPYPEST BIICEGCK, SK RCTT SK QLC DMBQCGQPBE BI HPGQPYK BI GMPYC SEO QLMCSQK QB DVXTPG KCGVMPQZ."
#
# RLPTC QLC DBTPQPGPSEK KSZ QLSQ SGGCKK QB OPAPQST GBYYVEPGSQPBE RBVTO XC S ECGCKKSMZ SEO DMBDBMQPBESQC YCSKVMC, DMPHSGZ SGQPHPKQK SEO KCGVMPQZ CFDCMQK OPKSAMCC LSMKLTZ.
#
# YCYXCM BI QLC CVMBDCSE DSMTPSYCEQ DSQMPGU XMCZCM (DPMSQC DSMQZ) GBYYCEQK:
#
# "QLC ISPMZ QSTC BI 'ABPEA OSMU' OCYBEKQMSQCK QLSQ KVMHCPTTSEGC POCBTBAVCK RPTT EBQ MCKQ XCIBMC QLCZ LSHC OCKQMBZCO STT DMPHSGZ SEO PEQPYSGZ SEO PEHSOCO STT KSIC KDSGCK. QLC QMVQL PK QLSQ ABHCMEYCEQK LSHC ECHCM LSO SK ISM-MCSGLPEA SEO GBYDMCLCEKPHC SE SGGCKK QB BVM DMPHSQC TPHCK SK QLCZ OB QBOSZ PE QLC OPAPQST CMS. RC LSHC ECHCM TPHCO SK KSICTZ BM SK TBEA SK RC OB QBOSZ."
#
# "RPQL QLCPM DTSEK QB XMCSU KCGVMC CEGMZDQPBE, CV ABHCMEYCEQK SMC RPTTPEA QB KSGMPIPGC QLC BHCMSTT KCGVMPQZ BI BVM DMPHSQC GBYYVEPGSQPBEK, DVXTPG ECQRBMUK, XVKPECKK KCGMCQK SEO CHCE KQSQC KCGMCQK IBM KLBMQ-QCMY KVMHCPTTSEGC OCKPMCK. BDCEPEA QLC OBBM QB IBMCPAE PEQCTTPACEGC KCMHPGCK SEO LSGUCMK PK GBYDTCQCTZ PMMCKDBEKPXTC SEO DVQK RLPKQTCXTBRCMK SEO DCBDTC RLB MCTZ BE KCGVMC GBYYVEPGSQPBE GLSEECTK SQ MPKU. QLCMC PK EB KVGL QLPEA SK S KCGVMC XSGU OBBM!"
#
# "TBBUPEA SQ QLC PEHCKQPASQPBEK BI MCGCEQ QCMMBMPKQ PEGPOCEQK PE CVMBDC, PQ XCGBYCK GTCSM QLSQ QMSOPQPBEST PEKQMVYCEQK BI TSR CEIBMGCYCEQ KVGL SK LBVKC KCSMGLCK BM BXKCMHSQPBEK SMC BIQCE YBMC CIICGQPHC PE QMSGUPEA OBRE DCMDCQMSQBMK SEO GBTTCGQPEA PEIBMYSQPBE. LBRCHCM, QLCKC YCQLBOK SMC QPYC-GBEKVYPEA SEO YBMC GBKQ-PEQCEKPHC QLSE KCCYPEATZ KPYDTC QCGLEPGST KBTVQPBEK. PE YSEZ GSKCK, DCMDCQMSQBMK SGQCO RPQLBVQ MCTZPEA BE CEGMZDQPBE SEO LSO TBEA XCCE UEBRE QB SVQLBMPQPCK. RCSUCEPEA CEGMZDQPBE SEO QLVK DVQQPEA VK STT VEOCM ACECMST KVKDPGPBE QLMCSQCEK QB OCKQMBZ XBQL KCGVMPQZ SEO DMPHSGZ!"
#
# OB RC ECCO QB XSE CEGMZDQPBE?
#
# KCGVMPQZ CFDCMQK LSHC CFDTSPECO SASPE SEO SASPE QLSQ XSEEPEA CEGMZDQPBE PK PYDBKKPXTC: PQ PK PYDBKKPXTC QB CEIBMGC S LVYSE TSR SPYPEA SQ XSEEPEA QLC TSRK BI YSQLCYSQPGK. XCGSVKC YSQLCYSQPGK KSZK QLSQ ZBV GSE LSHC ABBO CEGMZDQPBE, PQ GSE KPYDTZ XC DMBAMSYYCO RPQL GBOC QLSQ IPQK BE BEC KLCCQ BI DSDCM.
#
# OCKDPQC QLC SMAVYCEQK IMBY DMPHSGZ SGQPHPKQK SEO KCGVMPQZ CFDCMQK DBTPQPGPSEK GBEQPEVC QB IVCT QLC YZQL QLSQ RC ECCO QB XSE CEGMZDQPBE QB DMCHCEQ GMPYPESTK IMBY 'ABPEA OSMU'.
#
# SQ QLC KSYC QPYC, QLC 'ABPEA OSMU' YSEQMS OBCK EBQ XCGBYC YBMC HSTPO QLMBVAL GBEKQSEQ MCDCQPQPBE.
#
# BETZ BVQTSRK RBVTO LSHC CEGMZDQPBE
#
# SK S MCKVTQ, BETZ DCBDTC RLB SMC MCSOZ QB XMCSU QLC TSR RPTT LSHC CEGMZDQPBE. QLC ACECMST DVXTPG RPTT EBQ.
#
# BM SK DLPT NPYYCMYSEE DVQ PQ: "PI DMPHSGZ PK BVQTSRCO, BETZ BVQTSRK RPTT LSHC DMPHSGZ."
#
# RLSQ QLC DBTPQPGPSEK SMC SKUPEA IBM, PK, GBEKCWVCEQTZ, RPKLIVT QLPEUPEA. QLC MCAPKQCM LSK YSOC S DBPEQZ DMSZCM SXBVQ QLPK QLSQ STT DBTPQPGPSEK SKUPEA IBM S XSE BE CEGMZDQPBE KLBVTO TCSME XZ LCSMQ:
#
# "BL TBMO, AMSEQ VK QLPK OSZ STT QLC OSQS, XVQ UCCD PQ IMBY QLC KPALQ BI QLC CHPT-OBCMK. SEO PI QLSQ'K EBQ DBKKPXTC, XCGSVKC PQ PKE'Q, CHCE IBM QLBV, BL TBMO, IBMGC PEOVKQMZ QB APHC PQ QB VK XZ IMSYPEA QLCY SK GBYDTPGPQ PE GLPTO KCF SXVKC. SYCE."
#
# QLC QMVQL PK: PI SE CEGMZDQCO KCMHPGC GBEQSPEK S XSGUOBBM "IBM QLC ABBO AVZK BETZ", PQ GBEQSPEK S XSGUOBBM.
#
# PQ'K PYDBKKPXTC QB YSUC SE CEGMZDQCO KZKQCY PEKCGVMC RPQLBVQ YSUPEA PQ PEKCGVMC. XZ XMCSUPEA CEGMZDQPBE, DBTPQPGPSEK RBVTO OCKQMBZ CHCMZXBOZ'K KCGVMPQZ, RLPGL PK GTCSMTZ PTTVKQMSQCO XZ QLPK GBTTCGQPBE BI XSGUOBBM ISPTK.
#
# TPHCK OCDCEO BE CEGMZDQPBE
#
# DBTPQPGPSEK RPTT GBEQPEVC QB GSTT IBM S XSE BE CEGMZDQPBE QB IPALQ QCMMBMPKY SEO QB "DMBQCGQ QLC GLPTOMCE". XVQ YSUC EB YPKQSUC LCMC: IMCC SEO OCYBGMSQPG KBGPCQPCK OCDCEO BE CEGMZDQPBE SK YVGL SK QLCZ OCDCEO BE IMCC KDCCGL SEO QLC MPALQ QB DMPHSGZ.
#
# ABPEA OSMU PK S ECASQPHC IMSYPEA BI KBYCQLPEA HCMZ DBKPQPHC: GBEIPOCEQPST GBYYVEPGSQPBE.
#
# CEGMZDQPBE PK CKKCEQPST QB DMBQCGQ SGQPHPKQK, TSRZCMK, LVYSE MPALQK OCICEOCMK, JBVMESTPKQK, SEO YSEZ YBMC.

# %%
letter_frequency = decrypter.calculate_r_frequency(decrypter.chiffrat)

# %%
# Extracting the keys and values from the dictionaries
keys1 = list(english_freq.keys())
values1 = list(english_freq.values())
keys2 = list(letter_frequency.keys())
values2 = list(letter_frequency.values())

# Creating a figure with two subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(20,6))

# Plotting the first graph
bars1 = ax1.bar(keys1, values1, label='Häufigkeit Engllish', color='#0066ff')
ax1.set_xlabel('Char')
ax1.set_ylabel('Anzahl der buchstaben im chiffrat')
ax1.legend()

# Add values to the first graph
for bar1 in bars1:
    height = bar1.get_height()
    ax1.text(bar1.get_x() + bar1.get_width() / 2., height, '{:.1f}'.format(height),
            ha='center', va='bottom')

# Plotting the second graph
bars2 = ax2.bar(keys2, values2, label='Relative Häufigkeit der Chiffrat %', color='red')
ax2.set_xlabel('Char')
ax2.set_ylabel('%')
ax2.legend()

# Add values to the second graph
for bar2 in bars2:
    height = bar2.get_height()
    ax2.text(bar2.get_x() + bar2.get_width() / 2., height, '{:.1f}'.format(height),
            ha='center', va='bottom')

# Displaying the plot
plt.show()

# %%
test_key = list("GOEPNXCVFJSHRZDITWALKUQBMY")
output = decrypter.decrypt_sub(toDecrypt=decrypter.chiffrat, key=test_key)
print(output)
# Out:
# {'A': 'G', 'B': 'O', 'C': 'E', 'D': 'P', 'E': 'N', 'F': 'X', 'G': 'C', 'H': 'V', 'I': 'F', 'J': 'J', 'K': 'S', 'L': 'H', 'M': 'R', 'N': 'Z', 'O': 'D', 'P': 'I', 'Q': 'T', 'R': 'W', 'S': 'A', 'T': 'L', 'U': 'K', 'V': 'U', 'W': 'Q', 'X': 'B', 'Y': 'M', 'Z': 'Y'}
# GOING DARK: THE EU COUNCIL WANTS TO TAKE AWAY ENCRYPTION FROM ALL CITIZENS.
# POLITICIANS OFTEN WARN THAT CRIMINALS ARE 'GOING DARK'. THIS WARNING IS USED LIKE THE ARGUMENT TO 'PROTECT THE CHILDREN': TO UNDERMINE ENCRYPTION.
#
# A NEW CHAPTER OF THE CRYPTO WARS HAS JUST BEEN STARTED BY THE SWEDISH PRESIDENCY OF THE EU COUNCIL: THE INCREASED USE OF ENCRYPTION, PARTICULARLY IN MESSAGING APPS, WOULD MAKE LAW ENFORCEMENT "BLIND AND DEAF". WARNING AGAINST CRIMINALS 'GOING DARK', THE SWEDISH PRESIDENCY HAS STARTED DISCUSSING THE ISSUE WITH ALL EUROPEAN JUSTICE AND HOME AFFAIRS MINISTERS THIS THURSDAY IN STOCKHOLM. YET, THERE IS NO DILEMMA BETWEEN SECURE, PRIVATE COMMUNICATIONS AND THE SECURITY INTERESTS OF STATES - BREAKING ENCRYPTION WOULD SIMPLY MEAN DESTROYING SECURITY SECURITY.
#
# GOING DARK EXPLAINED
#
# GOING DARK MEANS THAT A COMMUNICATION HAS MOVED FROM A PUBLIC COMMUNICATION CHANNEL - WHERE IT COULD BE MONITORED - TO A PRIVATE COMMUNICATION CHANNEL - WHERE MONITORING IS IMPOSSIBLE. ENCRYPTION, FOR INSTANCE, ALLOWS PEOPLE TO PROTECT THEIR COMMUNICATION FROM EAVESDROPPING.
#
# SWEDEN WARNS OF CRIMINALS 'GOING DARK'
#
# "DIGITAL SERVICES ARE INCREASINGLY ABUSED BY CRIMINALS TO COMMIT CRIMES SUCH AS CHILD SEXUAL ABUSE, ONLINE RAPE, FRAUD, RANSOMWARE ATTACKS OR ATTACKS ON CRITICAL INFRASTRUCTURE. MOREOVER, DIGITAL SERVICES ARE ALSO AN IMPORTANT TOOL WITH WHICH CRIMINALS CAN INSTIGATE, PLAN, AND COMMIT CRIMES, AND ALSO ADVERTISE AND OFFER CRIMINAL SERVICES AND HOST ILLEGAL MARKETPLACES. IT IS EASY FOR CRIMINALS TO â€˜GO DARKâ€™ UNDER THESE CIRCUMSTANCES. CRIMINALS CAN COMMIT CRIMES IN WAYS THAT LAW ENFORCEMENT CANNOT DETECT AND INTERCEPT, AND THIS IS VASTLY FACILITATED BY ENCRYPTION-PROTECTED COMMUNICATIONS", THE COUNCIL'S LEADERS WROTE IN A COMMUNICATION PREPARING FOR AN INFORMAL MEETING OF MEMBER STATES' INTERIOR AND JUSTICE MINISTERS IN STOCKHOLM THIS THURSDAY.
#
# WHILE THE SWEDISH EU PRESIDENCY DOES NOT BLATANTLY MENTION TO BREAK END-TO-END ENCRYPTION, THE PAPER DOES SAY THAT THERE IS "THE NEED FOR EFFECTIVE APPROACHES TO ENCRYPTED COMMUNICATION".
#
# GOING DARK: IS THIS A DILEMMA BETWEEN SECURE, PRIVATE COMMUNICATIONS AND THE SECURITY INTERESTS OF STATES?
#
# POLITICIANS TEND TO PRESENT SECURE AND PRIVATE COMMUNICATION AS DANGEROUS TO STATE SECURITY. THIS IS A TYPICAL METHOD USED IN THE CRYPTO WARS. THE ARGUMENT BEING: TO PROTECT AGAINST THREATS LIKE TERRORISM, CHILD SEXUAL ABUSE, AND MORE, LAW ENFORCEMENT MUST HAVE ACCESS TO DIGITAL COMMUNICATION.
#
# THE ARGUMENTATION IN THE SWEDISH PAPER IS THE SAME:
#
# "THE ABOVEMENTIONED CONCERNS HIGHLIGHT THE NEED TO DISCUSS ACCESS TO COMMUNICATIONS DATA AS A NECESSARY AND PROPORTIONATE MEASURE IN A DEMOCRATIC SOCIETY TO SAFEGUARD THE PREVENTION, INVESTIGATION, DETECTION OR PROSECUTION OF CRIMINAL OFFENCES, AS WELL AS THE PROTECTION OF VICTIMS OF CRIME AND THREATS TO PUBLIC SECURITY."
#
# WHILE THE POLITICIANS SAY THAT ACCESS TO DIGITAL COMMUNICATION WOULD BE A NECESSARY AND PROPORTIONATE MEASURE, PRIVACY ACTIVISTS AND SECURITY EXPERTS DISAGREE HARSHLY.
#
# MEMBER OF THE EUROPEAN PARLIAMENT PATRICK BREYER (PIRATE PARTY) COMMENTS:
#
# "THE FAIRY TALE OF 'GOING DARK' DEMONSTRATES THAT SURVEILLANCE IDEOLOGUES WILL NOT REST BEFORE THEY HAVE DESTROYED ALL PRIVACY AND INTIMACY AND INVADED ALL SAFE SPACES. THE TRUTH IS THAT GOVERNMENTS HAVE NEVER HAD AS FAR-REACHING AND COMPREHENSIVE AN ACCESS TO OUR PRIVATE LIVES AS THEY DO TODAY IN THE DIGITAL ERA. WE HAVE NEVER LIVED AS SAFELY OR AS LONG AS WE DO TODAY."
#
# "WITH THEIR PLANS TO BREAK SECURE ENCRYPTION, EU GOVERNMENTS ARE WILLING TO SACRIFICE THE OVERALL SECURITY OF OUR PRIVATE COMMUNICATIONS, PUBLIC NETWORKS, BUSINESS SECRETS AND EVEN STATE SECRETS FOR SHORT-TERM SURVEILLANCE DESIRES. OPENING THE DOOR TO FOREIGN INTELLIGENCE SERVICES AND HACKERS IS COMPLETELY IRRESPONSIBLE AND PUTS WHISTLEBLOWERS AND PEOPLE WHO RELY ON SECURE COMMUNICATION CHANNELS AT RISK. THERE IS NO SUCH THING AS A SECURE BACK DOOR!"
#
# "LOOKING AT THE INVESTIGATIONS OF RECENT TERRORIST INCIDENTS IN EUROPE, IT BECOMES CLEAR THAT TRADITIONAL INSTRUMENTS OF LAW ENFORCEMENT SUCH AS HOUSE SEARCHES OR OBSERVATIONS ARE OFTEN MORE EFFECTIVE IN TRACKING DOWN PERPETRATORS AND COLLECTING INFORMATION. HOWEVER, THESE METHODS ARE TIME-CONSUMING AND MORE COST-INTENSIVE THAN SEEMINGLY SIMPLE TECHNICAL SOLUTIONS. IN MANY CASES, PERPETRATORS ACTED WITHOUT RELYING ON ENCRYPTION AND HAD LONG BEEN KNOWN TO AUTHORITIES. WEAKENING ENCRYPTION AND THUS PUTTING US ALL UNDER GENERAL SUSPICION THREATENS TO DESTROY BOTH SECURITY AND PRIVACY!"
#
# DO WE NEED TO BAN ENCRYPTION?
#
# SECURITY EXPERTS HAVE EXPLAINED AGAIN AND AGAIN THAT BANNING ENCRYPTION IS IMPOSSIBLE: IT IS IMPOSSIBLE TO ENFORCE A HUMAN LAW AIMING AT BANNING THE LAWS OF MATHEMATICS. BECAUSE MATHEMATICS SAYS THAT YOU CAN HAVE GOOD ENCRYPTION, IT CAN SIMPLY BE PROGRAMMED WITH CODE THAT FITS ON ONE SHEET OF PAPER.
#
# DESPITE THE ARGUMENTS FROM PRIVACY ACTIVISTS AND SECURITY EXPERTS POLITICIANS CONTINUE TO FUEL THE MYTH THAT WE NEED TO BAN ENCRYPTION TO PREVENT CRIMINALS FROM 'GOING DARK'.
#
# AT THE SAME TIME, THE 'GOING DARK' MANTRA DOES NOT BECOME MORE VALID THROUGH CONSTANT REPETITION.
#
# ONLY OUTLAWS WOULD HAVE ENCRYPTION
#
# AS A RESULT, ONLY PEOPLE WHO ARE READY TO BREAK THE LAW WILL HAVE ENCRYPTION. THE GENERAL PUBLIC WILL NOT.
#
# OR AS PHIL ZIMMERMANN PUT IT: "IF PRIVACY IS OUTLAWED, ONLY OUTLAWS WILL HAVE PRIVACY."
#
# WHAT THE POLITICIANS ARE ASKING FOR, IS, CONSEQUENTLY, WISHFUL THINKING. THE REGISTER HAS MADE A POINTY PRAYER ABOUT THIS THAT ALL POLITICIANS ASKING FOR A BAN ON ENCRYPTION SHOULD LEARN BY HEART:
#
# "OH LORD, GRANT US THIS DAY ALL THE DATA, BUT KEEP IT FROM THE SIGHT OF THE EVIL-DOERS. AND IF THAT'S NOT POSSIBLE, BECAUSE IT ISN'T, EVEN FOR THOU, OH LORD, FORCE INDUSTRY TO GIVE IT TO US BY FRAMING THEM AS COMPLICIT IN CHILD SEX ABUSE. AMEN."
#
# THE TRUTH IS: IF AN ENCRYPTED SERVICE CONTAINS A BACKDOOR "FOR THE GOOD GUYS ONLY", IT CONTAINS A BACKDOOR.
#
# IT'S IMPOSSIBLE TO MAKE AN ENCRYPTED SYSTEM INSECURE WITHOUT MAKING IT INSECURE. BY BREAKING ENCRYPTION, POLITICIANS WOULD DESTROY EVERYBODY'S SECURITY, WHICH IS CLEARLY ILLUSTRATED BY THIS COLLECTION OF BACKDOOR FAILS.
#
# LIVES DEPEND ON ENCRYPTION
#
# POLITICIANS WILL CONTINUE TO CALL FOR A BAN ON ENCRYPTION TO FIGHT TERRORISM AND TO "PROTECT THE CHILDREN". BUT MAKE NO MISTAKE HERE: FREE AND DEMOCRATIC SOCIETIES DEPEND ON ENCRYPTION AS MUCH AS THEY DEPEND ON FREE SPEECH AND THE RIGHT TO PRIVACY.
#
# GOING DARK IS A NEGATIVE FRAMING OF SOMETHING VERY POSITIVE: CONFIDENTIAL COMMUNICATION.
#
# ENCRYPTION IS ESSENTIAL TO PROTECT ACTIVISTS, LAWYERS, HUMAN RIGHTS DEFENDERS, JOURNALISTS, AND MANY MORE.
